# %% [markdown]
# <a href="https://colab.research.google.com/github/ghaniathar-sketch/Atrz/blob/main/F0403251004_Muhammad_Ghani_Athar_Tugas_Terstruktur_Bab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Reset folder & masuk
# %cd /content
# !rm -rf sistem-panen
# !mkdir sistem-panen
# %cd sistem-panen

# 2. Inisialisasi & Atur Branch Utama
# !git init
# !git branch -M main
# !git config --global user.name "ghaniathar-sketch"
# !git config --global user.email "ghaniathar@apps.ipb.ac.id"

# 3. POIN A: Buat file main.py & Commit Pertama
with open('main.py', 'w') as f:
    f.write("print('Program Panen')\n")

# !git add main.py
# !git commit -m "commit pertama: buat program panen"
# Out:
# /content
# /content/sistem-panen
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/sistem-panen/.git/
# [main (root-commit) 6aa56a4] commit pertama: buat program panen
#  1 file changed, 1 insertion(+)
#  create mode 100644 main.py

# %%
# !git checkout -b fitur-diskon

with open('main.py', 'a') as f:
    f.write("def diskon(): pass\n")

# !git add main.py
# !git commit -m "tambah fitur diskon"
# Out:
# Switched to a new branch 'fitur-diskon'
# [fitur-diskon 6c4d499] tambah fitur diskon
#  1 file changed, 1 insertion(+)

# %%
# !git checkout main
# !git merge fitur-diskon
# Out:
# Switched to branch 'main'
# Updating 5934e07..6c4d499
# Fast-forward
#  main.py | 1 +
#  1 file changed, 1 insertion(+)
